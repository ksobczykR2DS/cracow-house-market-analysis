# %% [markdown]
# # Data Analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %% [markdown]
# ## Collective data

# %%
df = pd.read_csv('../datasets/apartments_collective.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17932 entries, 0 to 17931
# Data columns (total 19 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Unnamed: 0                           17932 non-null  int64
#  1   url                                  17932 non-null  object
#  2   name/title                           17932 non-null  object
#  3   address                              17932 non-null  object
#  4   price                                17932 non-null  float64
#  5   area                                 17932 non-null  float64
#  6   price-per-area                       17932 non-null  float64
#  7   floor/store                          17932 non-null  int64
#  8   no of floors/stores in the building  17932 non-null  int64
#  9   no of rooms                          17932 non-null  int64
#  10  year of construction                 17932 non-null  float64
#  11  parking space                        17932 non-null  bool
#  12  market                               17932 non-null  object
#  13  form of ownership                    17932 non-null  object
#  14  location                             17932 non-null  object
#  15  latitude                             17932 non-null  float64
#  16  longitude                            17932 non-null  float64
#  17  distance                             17932 non-null  float64
#  18  district                             17932 non-null  object
# dtypes: bool(1), float64(7), int64(4), object(7)
# memory usage: 2.5+ MB

# %%
df.head()
# Out:
#    Unnamed: 0                                                url  \
# 0           0  https://krakow.nieruchomosci-online.pl/mieszka...
# 1           1  https://krakow.nieruchomosci-online.pl/mieszka...
# 2           2  https://krakow.nieruchomosci-online.pl/mieszka...
# 3           3  https://krakow.nieruchomosci-online.pl/mieszka...
# 4           4  https://krakow.nieruchomosci-online.pl/mieszka...
#
#                       name/title  \
# 0              Mieszkanie Kraków
# 1              Mieszkanie Kraków
# 2              Mieszkanie Kraków
# 3  Apartament, ul. 28 Lipca 1943
# 4  Mieszkanie, ul. 28 Lipca 1943
#
#                                              address      price    area  \
# 0         103171, Mistrzejowice, Kraków, małopolskie  1087000.0   74.80
# 1            2 Pułku Lotniczego, Kraków, małopolskie   550000.0   32.00
# 2            2 Pułku Lotniczego, Kraków, małopolskie   550000.0   32.30
# 3  28 Lipca 1943, Wola Justowska, Kraków, małopol...  2290000.0  155.16
# 4  28 Lipca 1943, Wola Justowska, Kraków, małopol...  2399000.0  139.00
#
#    price-per-area  floor/store  no of floors/stores in the building  \
# 0        14532.09            6                                    7
# 1        17187.50            4                                    8
# 2        17028.00            4                                   10
# 3        14758.96            0                                    2
# 4        17258.99            1                                    2
#
#    no of rooms  year of construction  parking space  market form of ownership  \
# 0            3                2016.0           True  wtórny    pełna własność
# 1            1                2012.0          False  wtórny    pełna własność
# 2            1                1985.0          False  wtórny    pełna własność
# 3            5                2009.0           True  wtórny    pełna własność
# 4            3                2022.0          False  wtórny    pełna własność
#
#                                             location   latitude  longitude  \
# 0  Mistrzejowice, Kraków, województwo małopolskie...  50.097426  20.009603
# 1  2, Osiedle 2 Pułku Lotniczego, Czyżyny, Kraków...  50.077806  20.012307
# 2  2, Osiedle 2 Pułku Lotniczego, Czyżyny, Kraków...  50.077806  20.012307
# 3  28 Lipca 1943, Wola Justowska, Zwierzyniec, Kr...  50.062710  19.872002
# 4  28 Lipca 1943, Wola Justowska, Zwierzyniec, Kr...  50.062710  19.872002
#
#    distance       district
# 0  6.500728  Mistrzejowice
# 1  5.639111        Czyżyny
# 2  5.639111        Czyżyny
# 3  4.662523    Zwierzyniec
# 4  4.662523    Zwierzyniec

# %%
# condition1 = df['area'] > 200
# condition2 = df['price-per-area'] > 60000
# condition3 = df['no of rooms'] > 10
# condition4 = (df['year of construction'] <= 1800)
# 
# outlier_conditions = condition1 | condition2 | condition3 | condition4
# 
# outlier_count = df[outlier_conditions].shape[0]
# print("Number of outliers:", outlier_count)
# 
# df = df[~outlier_conditions]

# %% [markdown]
# ### Preparing  data for analysis

# %%
# Drop unnecessary columns

columns_to_drop = ['Unnamed: 0', 'url', 'name/title', 'address', 'location', 'latitude', 'longitude', 'form of ownership', 'district', 'price']

df_reduced = df.drop(columns=columns_to_drop)

# %%
df_reduced['market'].unique()
# Out:
# array(['wtórny', 'pierwotny'], dtype=object)

# %%
df['form of ownership'].unique()
# Out:
# array(['pełna własność', 'spółdzielcze wł. prawo do lokalu', 'udział',
#        'użytkowanie wieczyste / dzierżawa'], dtype=object)

# %%
df_reduced['market'] = df_reduced['market'].map({'pierwotny': 0, 'wtórny': 1})

# %%
df_reduced['market'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
df_reduced.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17932 entries, 0 to 17931
# Data columns (total 9 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   area                                 17932 non-null  float64
#  1   price-per-area                       17932 non-null  float64
#  2   floor/store                          17932 non-null  int64
#  3   no of floors/stores in the building  17932 non-null  int64
#  4   no of rooms                          17932 non-null  int64
#  5   year of construction                 17932 non-null  float64
#  6   parking space                        17932 non-null  bool
#  7   market                               17932 non-null  int64
#  8   distance                             17932 non-null  float64
# dtypes: bool(1), float64(4), int64(4)
# memory usage: 1.1 MB

# %% [markdown]
# ### Pearson Correlation

# %%
colormap = plt.cm.viridis
plt.figure(figsize=(12,12))
plt.title('Pearson Correlation of Features', y=1.05, size=15)
sns.heatmap(df_reduced.astype(float).corr(), linewidths=0.1, vmax=1.0,
            square=True, cmap=colormap, linecolor='white', annot=True)
plt.show()

# %% [markdown]
# ### Prices in various districts

# %%
df['district'].unique()
# Out:
# array(['Mistrzejowice', 'Czyżyny', 'Zwierzyniec', 'Prądnik Biały',
#        'Bieżanów-Prokocim', 'Stare Miasto', 'Prądnik Czerwony',
#        'Bronowice', 'Bieńczyce', 'Krowodrza', 'Grzegórzki', 'Nowa Huta',
#        'Podgórze', 'Wzgórza Krzesławickie', 'Swoszowice', 'Dębniki',
#        'Podgórze Duchackie', 'Łagiewniki-Borek Fałęcki'], dtype=object)

# %%
sns.barplot(x='district', y='price-per-area', data=df, errorbar='sd', palette='viridis') 
plt.xticks(rotation=90)
plt.title('Average apartment prices in various districts')
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_18500\3983402080.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='district', y='price-per-area', data=df, errorbar='sd', palette='viridis')

# %% [markdown]
# ### PCA

# %%
attributes= list(df_reduced.columns.values)
values = df_reduced.values

# %%
attributes
# Out:
# ['area',
#  'price-per-area',
#  'floor/store',
#  'no of floors/stores in the building',
#  'no of rooms',
#  'year of construction',
#  'parking space',
#  'market',
#  'distance']

# %%
values
# Out:
# array([[74.8, 14532.09, 6, ..., True, 1, 6.500728235137685],
#        [32.0, 17187.5, 4, ..., False, 1, 5.639111140541514],
#        [32.3, 17028.0, 4, ..., False, 1, 5.639111140541514],
#        ...,
#        [79.0, 21500.0, 2, ..., False, 0, 1.5423261347254926],
#        [121.0, 22500.0, 2, ..., False, 0, 1.5423261347254926],
#        [26.0, 24577.0, 0, ..., False, 1, 2.695967269776532]], dtype=object)

# %% [markdown]
# #### Values normalization

# %%
scaler = StandardScaler()
normalized_values = scaler.fit_transform(df_reduced)

# %%
normalized_values
# Out:
# array([[ 0.63297187, -0.48521164,  1.7221561 , ...,  0.87313156,
#          0.76838876,  0.85357545],
#        [-0.88821641,  0.07962886,  0.77923212, ..., -1.14530278,
#          0.76838876,  0.50843759],
#        [-0.87755388,  0.04570112,  0.77923212, ..., -1.14530278,
#          0.76838876,  0.50843759],
#        ...,
#        [ 0.78224736,  0.99695412, -0.16369185, ..., -1.14530278,
#         -1.30142456, -1.1326111 ],
#        [ 2.27500222,  1.20966723, -0.16369185, ..., -1.14530278,
#         -1.30142456, -1.1326111 ],
#        [-1.10146711,  1.65147234, -1.10661583, ..., -1.14530278,
#          0.76838876, -0.67049721]])

# %%
pca = PCA()
X_pca = pca.fit_transform(normalized_values)

# %%
plt.figure(figsize=(9,6))
sns.barplot(x=attributes, y = pca.components_[0], order=np.array(attributes)[np.argsort(pca.components_[0])[::-1]],palette="viridis")
plt.xlabel('Component element')
plt.xticks(rotation=90)
plt.ylabel('Component value')
plt.title('First principal component')
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_18500\3293549524.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=attributes, y = pca.components_[0], order=np.array(attributes)[np.argsort(pca.components_[0])[::-1]],palette="viridis")

# %%
plt.figure(figsize=(9,6))
sns.barplot(x=attributes, y = pca.components_[1], order=np.array(attributes)[np.argsort(pca.components_[1])[::-1]],palette="viridis")
plt.xlabel('Component element')
plt.xticks(rotation=90)
plt.ylabel('Component value')
plt.title('Second principal component')
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_18500\2623869220.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=attributes, y = pca.components_[1], order=np.array(attributes)[np.argsort(pca.components_[1])[::-1]],palette="viridis")

# %%
plt.figure(figsize=(18,12))
sp = sns.scatterplot(x=X_pca[...,0], y=X_pca[...,1], hue=df['district'])

directions = pca.components_[:2,:] @ np.identity(len(attributes))*8

sp.quiver(
    np.zeros_like(directions[0,:]), 
    np.zeros_like(directions[1,:]),
    directions[0,:],
    directions[1,:],
    angles='xy',
    scale_units='xy',
    scale=1,
    color='green',
    width=0.005,
    zorder=20)

for i, txt in enumerate(attributes):
        plt.text(directions[0,i], directions[1,i], txt, fontsize=15, color='black')
        
plt.xlim([-5, 5])
plt.ylim([-4, 7])
    
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.legend(title='District')
plt.tight_layout()  
plt.show()

# %%
df.describe()
# Out:
#          Unnamed: 0         price          area  price-per-area   floor/store  \
# count  17932.000000  1.793200e+04  17932.000000    17932.000000  17932.000000
# mean    8997.164064  9.530099e+05     56.990767    16813.151355      2.347201
# std     5187.154819  6.314783e+05     28.136684     4701.298917      2.121121
# min        0.000000  2.000000e+03     10.270000       19.140000     -1.000000
# 25%     4518.750000  6.504498e+05     39.500000    14000.000000      1.000000
# 50%     9004.500000  8.000000e+05     51.010000    16200.000000      2.000000
# 75%    13487.250000  1.029451e+06     66.000000    18611.027500      3.000000
# max    17972.000000  1.600000e+07    550.000000   152594.090000     15.000000
#
#        no of floors/stores in the building   no of rooms  \
# count                         17932.000000  17932.000000
# mean                              4.792661      2.592907
# std                               2.409931      1.062390
# min                               1.000000      1.000000
# 25%                               3.000000      2.000000
# 50%                               4.000000      2.000000
# 75%                               6.000000      3.000000
# max                              18.000000     44.000000
#
#        year of construction      latitude     longitude      distance
# count          17932.000000  17932.000000  17932.000000  17932.000000
# mean            2003.309335     50.058524     19.953670      4.369826
# std               35.301044      0.029035      0.051288      2.496513
# min             1300.000000     49.977644     19.804653      0.039979
# 25%             2000.000000     50.035278     19.920141      2.455939
# 50%             2018.000000     50.063935     19.949310      3.985889
# 75%             2023.000000     50.081787     19.982958      6.111437
# max             2026.000000     50.119562     20.202296     18.928352
